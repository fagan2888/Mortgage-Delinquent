# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("DleqencyLoanData101419.csv")

# %%
df.head()
# Out:
#   ln_seq_number  mth_reprt_prd  curr_actl_upb curr_ln_delq_stas  ln_age  \
# 0  F117Q2000052         201707          61000                 1       2
# 1  F117Q2000101         201708          68000                 1       2
# 2  F117Q2000101         201709          68000                 1       3
# 3  F117Q2000115         201801          57722                 1       7
# 4  F117Q2000161         201805          38782                 1      12
#
#    remng_mth rep_flag mod_flag  zero_bal_cd  zero_bal_eff_dt  ...   exp_amt  \
# 0        358      NaN      NaN          NaN              NaN  ...       NaN
# 1        358      NaN      NaN          NaN              NaN  ...       NaN
# 2        357      NaN      NaN          NaN              NaN  ...       NaN
# 3        353      NaN      NaN          NaN              NaN  ...       NaN
# 4        349      NaN      NaN          NaN              NaN  ...       NaN
#
# ...

# %%
df.describe(include ='all')
# Out:
#        ln_seq_number  mth_reprt_prd  curr_actl_upb curr_ln_delq_stas  \
# count          21264   21264.000000   2.126400e+04             21264
# unique          8754            NaN            NaN                13
# top     F117Q2010042            NaN            NaN                 1
# freq              12            NaN            NaN             13314
# mean             NaN  201768.449351   2.340051e+05               NaN
# std              NaN      44.983708   1.233974e+05               NaN
# min              NaN  201706.000000   0.000000e+00               NaN
# 25%              NaN  201711.000000   1.382320e+05               NaN
# 50%              NaN  201802.000000   2.150000e+05               NaN
# 75%              NaN  201804.000000   3.190000e+05               NaN
# max              NaN  201806.000000   1.198490e+06               NaN
#
#               ln_age     remng_mth rep_flag mod_flag  zero_bal_cd  \
# count   21264.000000  21264.000000      206      544   203.000000
# ...

# %%
df.describe()
# Out:
#        mth_reprt_prd  curr_actl_upb        ln_age     remng_mth  zero_bal_cd  \
# count   21264.000000   2.126400e+04  21264.000000  21264.000000   203.000000
# mean   201768.449351   2.340051e+05      7.477662    329.404251     1.162562
# std        44.983708   1.233974e+05      2.892299     61.790348     0.953460
# min    201706.000000   0.000000e+00      0.000000      0.000000     1.000000
# 25%    201711.000000   1.382320e+05      5.000000    349.000000     1.000000
# 50%    201802.000000   2.150000e+05      8.000000    352.000000     1.000000
# 75%    201804.000000   3.190000e+05     10.000000    355.000000     1.000000
# max    201806.000000   1.198490e+06     13.000000    480.000000     9.000000
#
#        zero_bal_eff_dt   curr_int_rt  curr_defrd_upb          ddlpi  mi_upb  \
# count       203.000000  21264.000000    21264.000000    2082.000000     0.0
# mean     201779.448276      4.469682        5.348429  201782.277137     NaN
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.plot("eltv","ln_age", kind = "scatter")

# %%
df.dtypes
# Out:
# ln_seq_number         object
# mth_reprt_prd          int64
# curr_actl_upb          int64
# curr_ln_delq_stas     object
# ln_age                 int64
# remng_mth              int64
# rep_flag              object
# mod_flag              object
# zero_bal_cd          float64
# zero_bal_eff_dt      float64
# curr_int_rt          float64
# curr_defrd_upb         int64
# ddlpi                float64
# mi_upb               float64
# net_sls_amt          float64
# non_mi_amt           float64
# exp_amt              float64
# lgl_cst              float64
# other_cst            float64
# ti_ins_cst           float64
# misc_exp             float64
# loss_cal             float64
# mod_cst              float64
# step_mod_flag         object
# dfrd_pmt_mod          object
# eltv                 float64
# dtype: object

# %%
df.hist(column =["ln_age","eltv","remng_mth"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DC92FB75F8>,
# ...
#       dtype=object)

# %%
sns.lmplot(x ="eltv", y= "ln_age",data =df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x ="eltv", y= "ln_age", data =df, fit_reg=False, hue ="remng_mth")

# %%
sns.distplot(df["ln_age"])
