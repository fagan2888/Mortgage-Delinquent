# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("DleqencyLoanJoinData101419.csv")

# %%
df.head()
# Out:
#    credit_score  first_payment_date first_time_homebuyer_flag  maturity_date  \
# 0           681              201706                         9         204705
# 1           660              201706                         9         204705
# 2           679              201707                         9         204706
# 3           713              201706                         9         204705
# 4           713              201706                         9         204705
#
#    msa_code  mi_percent  unit_cnt occupancy_status  orig_cltv  \
# 0       NaN           0         1                P         28
# 1   30460.0           0         1                P         74
# 2   44060.0           0         1                P         52
# 3   40060.0           0         1                P         62
# 4   40060.0           0         1                P         62
#
#    orig_debt_to_inc  ...   exp_amt  lgl_cst  other_cst ti_ins_cst misc_exp  \
# ...

# %%
df.describe(include ='all')
# Out:
#         credit_score  first_payment_date first_time_homebuyer_flag  \
# count   42528.000000        42528.000000                     42528
# unique           NaN                 NaN                         3
# top              NaN                 NaN                         9
# freq             NaN                 NaN                     19784
# mean      707.494921       201707.059114                       NaN
# std        79.849076            1.536089                       NaN
# min       600.000000       201705.000000                       NaN
# 25%       671.000000       201706.000000                       NaN
# 50%       703.000000       201707.000000                       NaN
# 75%       743.000000       201708.000000                       NaN
# max      9999.000000       201803.000000                       NaN
#
#         maturity_date      msa_code    mi_percent      unit_cnt  \
# count    42528.000000  39208.000000  42528.000000  42528.000000
# ...

# %%
df.describe()
# Out:
#        credit_score  first_payment_date  maturity_date      msa_code  \
# count  42528.000000        42528.000000   42528.000000  39208.000000
# mean     707.494921       201707.059114  204501.710638  30811.265354
# std       79.849076            1.536089     504.154771  10270.231448
# min      600.000000       201705.000000  202705.000000  10180.000000
# 25%      671.000000       201706.000000  204705.000000  22744.000000
# 50%      703.000000       201707.000000  204706.000000  33124.000000
# 75%      743.000000       201708.000000  204707.000000  38060.000000
# max     9999.000000       201803.000000  204802.000000  49740.000000
#
#          mi_percent      unit_cnt     orig_cltv  orig_debt_to_inc  \
# count  42528.000000  42528.000000  42528.000000      42528.000000
# mean       9.096031      1.036447     77.885158         37.918642
# std       12.988321      0.267783     15.304479         15.402781
# min        0.000000      1.000000      9.000000          2.000000
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.plot("eltv","orig_cltv", kind = "scatter")

# %%
df.dtypes
# Out:
# credit_score                   int64
# first_payment_date             int64
# first_time_homebuyer_flag     object
# maturity_date                  int64
# msa_code                     float64
# mi_percent                     int64
# unit_cnt                       int64
# occupancy_status              object
# orig_cltv                      int64
# orig_debt_to_inc               int64
# orig_upb                       int64
# orig_ltv                       int64
# orig_int_rate                  int64
# channel                       object
# ppm_flag                      object
# product_type                  object
# property_st                   object
# property_type                 object
# postal_code                    int64
# ln_seq_number                 object
# ln_purpose                    object
# orig_ln_term                   int64
# borrower_cnt                   int64
# seller_name                   object
# servicer_name                 object
# ...

# %%
df.hist(column =["ln_age","eltv","remng_mth"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DC93F8C470>,
# ...
#       dtype=object)

# %%
sns.lmplot(x ="eltv", y= "orig_cltv",data =df)

# %%
sns.lmplot(x ="eltv", y= "ln_age", data =df, fit_reg=False, hue ="msa_code")

# %%
sns.distplot(df["ln_age"])

# %%
sns.distplot(df["ln_age"])
